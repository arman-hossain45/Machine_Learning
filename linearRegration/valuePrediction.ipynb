# %%
import pandas as pd
from matplotlib import pyplot as plt
df=pd.read_csv("nasdaq100.csv",sep=";")
df.head()
# Out:
#        Date  Starting (USD)  Ending (USD)
# 0  01.01.24           16800         16500
# 1  01.12.23           15900         16100
# 2  01.11.23           15800         15300
# 3  01.10.23           16100         16200
# 4  01.09.23           16300         15700

# %%
df.isnull().sum()
# Out:
# Date              0
# Starting (USD)    0
# Ending (USD)      0
# dtype: int64

# %%
df=df.drop(columns=["Date"])
df.head()
# Out:
#    Starting (USD)  Ending (USD)
# 0           16800         16500
# 1           15900         16100
# 2           15800         15300
# 3           16100         16200
# 4           16300         15700

# %%
plt.scatter(df['Starting (USD)'],df['Ending (USD)'])
plt.xlabel('Starting (USD)')
plt.ylabel('Ending (USD)')
plt.title('Stock prices')
# Out:
# Text(0.5, 1.0, 'Stock prices')

# %%
import matplotlib.pyplot as plt

# Scatter plot
plt.scatter(df['Starting (USD)'], df['Ending (USD)'], color="blue", label="Stocks")

# Add reference line y = x
min_val = min(df['Starting (USD)'].min(), df['Ending (USD)'].min())
max_val = max(df['Starting (USD)'].max(), df['Ending (USD)'].max())
plt.plot([min_val, max_val], [min_val, max_val], color="red", linestyle="--", label="y = x")

# Labels and title
plt.xlabel("Starting (USD)")
plt.ylabel("Ending (USD)")
plt.title("Stock Prices: Starting vs Ending")
plt.legend()
plt.show()
